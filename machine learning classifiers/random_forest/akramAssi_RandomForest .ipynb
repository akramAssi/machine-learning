# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn import tree
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import tree

data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target

X = df.loc[0:1000, df.columns != 'target']
y = df.loc[0:1000, 'target'].values

X_train, X_test, Y_train, Y_test = train_test_split(X, y, random_state=0)

rf = RandomForestClassifier(n_estimators=100,
                            random_state=0)
rf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
y_p=rf.predict(X_test)

print(" accuracy RandomForestClassifier",str(accuracy_score(Y_test, y_p)))
# Out:
#  accuracy RandomForestClassifier 0.972027972027972

# %%
fn=data.feature_names
cn=data.target_names
# fig= plt.subplots(nrows = 1,ncols = 1, dpi=800)
print("first Decision Tree in Random Forest")
# tree.plot_tree(rf.estimators_[0],
#                feature_names = fn, 
#                class_names=cn,
#                filled = True);
# # fig.savefig('rf_individualtree.png')
import graphviz 
dot_data = tree.export_graphviz(rf.estimators_[0], out_file=None, 
                     feature_names=fn,  
                     class_names=cn,  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph
    
#     display(graphviz.Source(dot_data))
# Out:
# first Decision Tree in Random Forest

# %%
print("second Decision Tree in Random Forest")
dot_data = tree.export_graphviz(rf.estimators_[1], out_file=None, 
                     feature_names=fn,  
                     class_names=cn,  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  

# graph.render(" Breast Cancer Dataset") 
graph
# Out:
# second Decision Tree in Random Forest

# %%
print("30th Decision Tree in Random Forest")
dot_data = tree.export_graphviz(rf.estimators_[30], out_file=None, 
                     feature_names=fn,  
                     class_names=cn,  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  

# graph.render(" Breast Cancer Dataset") 
graph
# Out:
# 30th Decision Tree in Random Forest

# %%
print("last Decision Tree in Random Forest")
dot_data = tree.export_graphviz(rf.estimators_[99], out_file=None, 
                     feature_names=fn,  
                     class_names=cn,  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  

# graph.render(" Breast Cancer Dataset") 
graph
# Out:
# last Decision Tree in Random Forest

# %% [markdown]
# # DecisionTree

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)
y_p1=clf.predict(X_test)

from sklearn.metrics import accuracy_score
print(" accuracy RandomForestClassifier",str(accuracy_score(Y_test, y_p1)))
# Out:
#  accuracy RandomForestClassifier 1.0

# %% [markdown]
# This accuracy indicates that an overfitting occurred

# %%
dot_data = tree.export_graphviz(clf, out_file=None, 
                     feature_names=fn,  
                     class_names=cn,  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  

# graph.render(" Breast Cancer Dataset") 
graph
